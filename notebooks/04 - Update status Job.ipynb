# %% [markdown]
# Grava na tabela de controle o sucesso da execução do Job:

# %%
spark.sql(f"INSERT INTO databricks_cnpj_data_lakehouse.bronze.controle_execucao_job VALUES ('databricks-cnpj-data-lakehouse-job', current_timestamp())")
